# %%
import pandas as pd

data = pd.read_csv("programming.csv")
print(data)
# Out:
#                                         code    language
# 0                       print('Hello World')      Python
# 1                         print('Sum =',a+b)      Python
# 2                for i in range(5): print(i)      Python
# 3                   def add(a,b): return a+b      Python
# 4                         import numpy as np      Python
# 5                           print(len(list))      Python
# 6                        x=[1,2,3]; print(x)      Python
# 7                       if x>5: print('big')      Python
# 8                          #include<stdio.h>           C
# 9                     printf('Hello World');           C
# 10                     int main(){return 0;}           C
# 11                           scanf('%d',&a);           C
# 12                                 int a=10;           C
# 13     for(int i=0;i<5;i++){printf('%d',i);}           C
# 14                           float num=10.5;           C
# 15                            char name[20];           C
# 16              System.out.println('Hello');        Java
# 17                       public class Test{}        Java
# 18                                  int a=5;        Java
# 19                    for(int i=0;i<5;i++){}        Java
# 20        Scanner sc=new Scanner(System.in);        Java
# 21                       String name='John';        Java
# 22                        class HelloWorld{}        Java
# 23  public static void main(String args[]){}        Java
# 24                     console.log('Hello');  JavaScript
# 25                                 let x=10;  JavaScript
# 26            function add(a,b){return a+b;}  JavaScript
# 27           document.getElementById('demo')  JavaScript
# 28                          var name='John';  JavaScript
# 29                          alert('Welcome')  JavaScript
# 30                    for(let i=0;i<5;i++){}  JavaScript
# 31                            const pi=3.14;  JavaScript

# %%
print(data.shape)
print(data['language'].value_counts())
# Out:
# (32, 2)
# language
# Python        8
# C             8
# Java          8
# JavaScript    8
# Name: count, dtype: int64

# %%
# Import libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
import pickle

# Load dataset
data = pd.read_csv("programming.csv")

print("Dataset Preview:")
print(data.head())

# Split input and output
X = data['code']
y = data['language']

# Convert text to numbers
vectorizer = CountVectorizer()
X_vectorized = vectorizer.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_vectorized, y, test_size=0.2, random_state=42
)

# Train Naive Bayes model
model = MultinomialNB()
model.fit(X_train, y_train)

# Test model
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print("\nModel Accuracy:", accuracy)

# Test prediction
sample = ["print('Hello World')"]

sample_vector = vectorizer.transform(sample)
prediction = model.predict(sample_vector)

print("\nSample Code:", sample[0])
print("Predicted Language:", prediction[0])

# Save model and vectorizer
pickle.dump(model, open("model.pkl","wb"))
pickle.dump(vectorizer, open("vectorizer.pkl","wb"))

print("\nModel and vectorizer saved successfully.")

import pickle

pickle.dump(model, open("model.pkl","wb"))
pickle.dump(vectorizer, open("vectorizer.pkl","wb"))
# Out:
# Dataset Preview:
#                           code language
# 0         print('Hello World')   Python
# 1           print('Sum =',a+b)   Python
# 2  for i in range(5): print(i)   Python
# 3     def add(a,b): return a+b   Python
# 4           import numpy as np   Python
#
# Model Accuracy: 0.14285714285714285
#
# Sample Code: print('Hello World')
# Predicted Language: Python
#
# Model and vectorizer saved successfully.

# %%
import pickle

pickle.dump(model, open("model.pkl","wb"))
pickle.dump(vectorizer, open("vectorizer.pkl","wb"))
from google.colab import files
files.download("model.pkl")
files.download("vectorizer.pkl")
